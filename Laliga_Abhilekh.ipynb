# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r'D:\\Downloads\\stayhome\\laliga.csv')

# %%
df.head()
# Out:
#   Unnamed: 0       Unnamed: 1 Unnamed: 2 Unnamed: 3   Unnamed: 4 Unnamed: 5  \
# 0        Pos             Team    Seasons     Points  GamesPlayed   GamesWon
# 1          1      Real Madrid         86       4385         2762       1647
# 2          2        Barcelona         86       4262         2762       1581
# 3          3  Atletico Madrid         80       3442         2614       1241
# 4          4         Valencia         82       3386         2664       1187
#
#    Unnamed: 6 Unnamed: 7 Unnamed: 8    Unnamed: 9 Unnamed: 10 Unnamed: 11  \
# 0  GamesDrawn  GamesLost   GoalsFor  GoalsAgainst    Champion   Runner-up
# 1         552        563       5947          3140          33          23
# 2         573        608       5900          3114          25          25
# 3         598        775       4534          3309          10           8
# 4         616        861       4398          3469           6           6
#
# ...

# %% [markdown]
# ## question 1

# %%
#changing header to 1st row
new_header = df.iloc[0]
df = df[1:]
df.columns = new_header

# %%
df.head()
# Out:
# 0 Pos             Team Seasons Points GamesPlayed GamesWon GamesDrawn  \
# 1   1      Real Madrid      86   4385        2762     1647        552
# 2   2        Barcelona      86   4262        2762     1581        573
# 3   3  Atletico Madrid      80   3442        2614     1241        598
# 4   4         Valencia      82   3386        2664     1187        616
# 5   5  Athletic Bilbao      86   3368        2762     1209        633
#
# 0 GamesLost GoalsFor GoalsAgainst Champion Runner-up Third Fourth Fifth Sixth  \
# 1       563     5947         3140       33        23     8      8     3     4
# 2       608     5900         3114       25        25    12     12     4     6
# 3       775     4534         3309       10         8    16      9     7     6
# 4       861     4398         3469        6         6    10     11    10     7
# 5       920     4631         3700        8         7    10      5     8    10
#
# 0   T    Debut Since/LastApp BestPosition
# ...

# %%
df=df.replace('-',0) #converting objects into int to perform arithmetic operations

# %%
df['Points']=df['Points'].astype(int)
df['Seasons']=df['Seasons'].astype(int)
df['GamesPlayed']=df['GamesPlayed'].astype(int)
df['GamesWon']=df['GamesWon'].astype(int)
df['GamesLost']=df['GamesLost'].astype(int)
df['GoalsFor']=df['GoalsFor'].astype(int)
df['GoalsAgainst']=df['GoalsAgainst'].astype(int)
df['Champion']=df['Champion'].astype(int)
df['Runner-up']=df['Runner-up'].astype(int)
df['Third']=df['Third'].astype(int)
df['Fourth']=df['Fourth'].astype(int)
df['Fifth']=df['Fifth'].astype(int)
df['Sixth']=df['Sixth'].astype(int)
df['T']=df['T'].astype(int)
df['BestPosition']=df['BestPosition'].astype(int)

# %%
df.dtypes
# Out:
# 0
# Pos              object
# Team             object
# Seasons           int32
# Points            int32
# GamesPlayed       int32
# GamesWon          int32
# GamesDrawn       object
# GamesLost         int32
# GoalsFor          int32
# GoalsAgainst      int32
# Champion          int32
# Runner-up         int32
# Third             int32
# Fourth            int32
# Fifth             int32
# Sixth             int32
# T                 int32
# Debut            object
# Since/LastApp    object
# BestPosition      int32
# dtype: object

# %%
df.iloc[1,:]
# Out:
# 0
# Pos                      2
# Team             Barcelona
# Seasons                 86
# Points                4262
# GamesPlayed           2762
# GamesWon              1581
# GamesDrawn             573
# GamesLost              608
# GoalsFor              5900
# GoalsAgainst          3114
# Champion                25
# Runner-up               25
# Third                   12
# Fourth                  12
# Fifth                    4
# Sixth                    6
# T                       83
# Debut                 1929
# Since/LastApp         1929
# BestPosition             1
# Name: 2, dtype: object

# %%
df=df.replace('-',0)

# %%
df.head()
# Out:
# 0 Pos             Team  Seasons  Points  GamesPlayed  GamesWon GamesDrawn  \
# 1   1      Real Madrid       86    4385         2762      1647        552
# 2   2        Barcelona       86    4262         2762      1581        573
# 3   3  Atletico Madrid       80    3442         2614      1241        598
# 4   4         Valencia       82    3386         2664      1187        616
# 5   5  Athletic Bilbao       86    3368         2762      1209        633
#
# 0  GamesLost  GoalsFor  GoalsAgainst  Champion  Runner-up  Third  Fourth  \
# 1        563      5947          3140        33         23      8       8
# 2        608      5900          3114        25         25     12      12
# 3        775      4534          3309        10          8     16       9
# 4        861      4398          3469         6          6     10      11
# 5        920      4631          3700         8          7     10       5
#
# 0  Fifth  Sixth   T    Debut Since/LastApp  BestPosition
# ...

# %% [markdown]
# ## Question 2

# %%
df['Debut'] = df['Debut'].astype(str).str[:4].astype(int)
df_new = df[df['Debut'].between(1930, 1980)]

# %%
df_new['Team']
# Out:
# 4                Valencia
# 6                 Sevilla
# 9                Zaragoza
# 10             Real Betis
# 11    Deportivo La Coruna
# 12             Celta Vigo
# 13             Valladolid
# 15         Sporting Gijon
# 16                Osasuna
# 17                 Malaga
# 18                 Oviedo
# 19               Mallorca
# 20             Las Palmas
# 22                Granada
# 23         Rayo Vallecano
# 24                  Elche
# 26               Hercules
# 27               Tenerife
# 28                 Murcia
# 29                 Alaves
# 30                Levante
# 31              Salamanca
# 32               Sabadell
# 33                  Cadiz
# 35              Castellon
# 38                Cordoba
# 40             Recreativo
# 41              Burgos CF
# 42             Pontevedra
# 47              Gimnastic
# 50               Alcoyano
# 51                   Jaen
# 53             AD Almeria
# 55                 Lleida
# 58                 Condal
# ...

# %% [markdown]
# ## Question 3

# %%
top5points = df.nlargest(5, 'Points')
top5points['Team']
# Out:
# 1        Real Madrid
# 2          Barcelona
# 3    Atletico Madrid
# 4           Valencia
# 5    Athletic Bilbao
# Name: Team, dtype: object

# %% [markdown]
# ## Question 4

# %%
df['Goal_diff_count'] = df['GoalsFor']-df['GoalsAgainst']

# %%
df.head()
# Out:
# 0 Pos             Team  Seasons  Points  GamesPlayed  GamesWon GamesDrawn  \
# 1   1      Real Madrid       86    4385         2762      1647        552
# 2   2        Barcelona       86    4262         2762      1581        573
# 3   3  Atletico Madrid       80    3442         2614      1241        598
# 4   4         Valencia       82    3386         2664      1187        616
# 5   5  Athletic Bilbao       86    3368         2762      1209        633
#
# 0  GamesLost  GoalsFor  GoalsAgainst  ...  Runner-up  Third  Fourth  Fifth  \
# 1        563      5947          3140  ...         23      8       8      3
# 2        608      5900          3114  ...         25     12      12      4
# 3        775      4534          3309  ...          8     16       9      7
# 4        861      4398          3469  ...          6     10      11     10
# 5        920      4631          3700  ...          7     10       5      8
#
# 0  Sixth   T  Debut  Since/LastApp BestPosition  Goal_diff_count
# ...

# %% [markdown]
# ## Question 5

# %%
df['Percentage of Winning'] = (df['GamesWon'] / df['GamesPlayed'])*100
df['Percentage of Winning'] = df['Percentage of Winning'].fillna(0)

# %%
df.head()
# Out:
# 0 Pos             Team  Seasons  Points  GamesPlayed  GamesWon GamesDrawn  \
# 1   1      Real Madrid       86    4385         2762      1647        552
# 2   2        Barcelona       86    4262         2762      1581        573
# 3   3  Atletico Madrid       80    3442         2614      1241        598
# 4   4         Valencia       82    3386         2664      1187        616
# 5   5  Athletic Bilbao       86    3368         2762      1209        633
#
# 0  GamesLost  GoalsFor  GoalsAgainst  ...  Third  Fourth  Fifth  Sixth   T  \
# 1        563      5947          3140  ...      8       8      3      4  79
# 2        608      5900          3114  ...     12      12      4      6  83
# 3        775      4534          3309  ...     16       9      7      6  56
# 4        861      4398          3469  ...     10      11     10      7  50
# 5        920      4631          3700  ...     10       5      8     10  49
#
# ...

# %%
winpercent5 = df.nlargest(5, 'Percentage of Winning')

# %%
winpercent5['Team']
# Out:
# 1        Real Madrid
# 2          Barcelona
# 3    Atletico Madrid
# 4           Valencia
# 5    Athletic Bilbao
# Name: Team, dtype: object

# %% [markdown]
# ## Question no 6

# %%
df.groupby(['BestPosition'])['Points'].sum()
# Out:
# BestPosition
# 1     27933
# 2      6904
# 3      5221
# 4      6563
# 5      1884
# 6      2113
# 7      1186
# 8      1134
# 9        96
# 10      450
# 11      445
# 12      511
# 14       71
# 15       14
# 16       81
# 17      266
# 19       81
# 20       34
# Name: Points, dtype: int32
